# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import cv2
import os
import matplotlib.pyplot as plt
import pickle
from keras.models import Sequential, Model
from keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, UpSampling2D,Concatenate, Cropping2D, ZeroPadding2D
import tensorflow as tf
import random
import keras
from keras.callbacks import Callback, ModelCheckpoint
from keras import backend as K
from tensorflow.keras.models import load_model
from IPython.display import clear_output
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import roc_curve, auc
import matplotlib
seed = 2019
np.random.seed = seed
random.seed = seed
tf.seed = seed
path = '/home/von/Downloads/archive(1)/Dataset'

# %%
from IPython.display import Image

# %% [markdown]
# # Preprocessing

# %%
#image_id_list = train['image_id'].unique().tolist()
image_id_list = os.listdir(path+'/Nepceleb_sketch')

# %%
#image_id_list = sum(image_id_list,[])
print(len(image_id_list),image_id_list)
# Out:
# 1626 ['001306.jpg', '000613.png', '000739.jpg', '001049.jpg', '000036.jpg', '000131.png', '001026.jpg', '000218.jpg', '000957.jpg', '001105.jpg', '000761.jpg', '000916.jpg', '000805.jpg', '001465.jpg', '000355.jpg', '001523.jpg', '000172.png', '000497.jpg', '001183.jpg', '000625.jpg', '000294.JPG', '001264.jpg', '001112.jpg', '001387.jpg', '001538.jpg', '000464.jpg', '000129.jpg', '000251.jpg', '000934.jpg', '000636.jpg', '000658.jpg', '000226.jpg', '000061.jpg', '000787.jpg', '000142.jpg', '000847.jpg', '000423.jpg', '000704.jpg', '001597.jpg', '000313.jpg', '000548.jpg', '000992.jpg', '001350.jpg', '000273.jpg', '000530.jpg', '000507.jpg', '000727.jpg', '000773.jpg', '001437.jpg', '000356.jpg', '001165.jpg', '000235.jpg', '000846.jpg', '001273.jpg', '000555.jpg', '000428.jpg', '000967.jpg', '000958.jpg', '000025.jpg', '000092.jpg', '000641.jpg', '000078.jpg', '001304.jpg', '001218.jpg', '000742.jpg', '000029.jpg', '000463.jpeg', '000984.jpg', '000554.jpg', '000605.jpg', '000807.jpg', '000521.jpg', '001435.jpg', '001180.jpg', '000482.jpg', '000744.jpg', '001125.jpg', '000237.jpg', '000417.jpg', '001150.jpg', '000909.jpg', '000735.jpg', '000877.jpg', '001239.jpg', '001268.JPG', '000296.jpg', '001497.jpg', '000295.jpg', '000115.jpg', '001601.jpg', '001456.jpg', '001243.jpg', '001607.jpg', '001449.jpg', '001407.jpg', '000230.jpg', '000853.jpg', '001315.jpg', '000500.jpg', '000498.jpg', '000153.jpg', '001467.jpg', '000077.png', '001093.jpg', '001447.jpg', '001101.jpg', '000580.jpg', '000363.jpg', '000217.jpg', '001328.jpg', '000318.jpg', '001176.jpeg', '001566.jpg', '000569.jpg', '000824.jpg', '001632.jpg', '001037.jpg', '001526.jpg', '000444.jpg', '001336.jpg', '000270.jpg', '000501.jpg', '001024.png', '000035.jpg', '000538.jpg', '000390.jpg', '000202.jpg', '001486.jpg', '000574.jpg', '001076.jpg', '000017.jpg', '000065.jpg', '000514.jpg', '000899.jpg', '001396.jpg', '000085.jpg', '000468.jpg', '000951.jpg', '001448.jpg', '000122.jpg', '000815.jpg', '000771.jpg', '000612.jpg', '001540.png', '000618.jpg', '001565.jpg', '000014.jpeg', '001341.jpg', '001194.jpg', '000045.jpg', '001587.jpg', '000149.jpg', '000823.jpg', '001432.jpg', '000861.jpg', '000070.jpg', '000835.jpg', '000179.jpg', '000123.jpg', '000589.jpg', '000457.jpg', '001073.jpg', '000925.jpg', '000406.jpg', '000091.jpg', '001164.jpg', '000059.jpg', '000409.jpg', '000784.jpg', '000147.jpg', '001235.jpg', '000483.jpg', '001603.jpg', '001563.jpg', '001374.jpg', '000760.png', '000303.jpg', '000798.jpg', '000069.jpg', '000587.jpg', '000247.jpg', '000204.jpg', '001386.jpg', '000898.jpg', '000557.jpg', '000643.jpg', '000020.jpg', '001404.jpg', '001229.jpg', '000801.jpg', '000920.jpg', '001411.jpg', '001252.jpg', '000110.jpg', '000921.jpg', '000510.png', '001380.jpg', '001275.jpg', '000888.jpg', '001320.jpg', '000726.jpg', '001375.jpg', '001492.jpg', '001056.jpg', '000938.jpg', '000720.jpg', '000348.JPG', '001480.jpg', '000788.jpg', '000794.jpg', '001479.jpg', '000044.jpg', '000581.jpg', '000812.jpg', '000370.jpg', '000933.jpg', '000249.jpg', '000871.png', '001175.jpg', '000995.jpg', '000320.jpg', '000048.png', '000201.jpg', '001053.jpg', '000493.jpg', '001016.jpg', '000932.jpg', '001192.jpg', '000694.jpg', '000400.jpg', '001564.jpg', '001117.jpg', '000743.jpg', '000831.jpg', '000706.jpg', '001506.jpg', '000446.jpg', '000403.jpg', '001531.jpg', '001288.jpg', '001310.jpg', '000093.png', '000881.png', '000570.jpg', '000053.jpg', '001559.jpg', '001167.jpg', '000319.jpg', '001018.jpg', '000634.jpg', '000515.jpg', '000786.jpg', '000981.jpg', '000973.jpg', '000759.jpg', '000672.jpg', '000608.jpg', '000241.jpg', '000388.jpg', '001223.jpg', '000662.jpg', '000868.jpg', '000879.JPG', '001074.png', '000725.jpg', '001190.jpg', '000264.jpg', '001358.jpg', '001197.jpg', '000537.jpg', '001184.jpg', '001446.jpg', '001287.jpg', '001553.jpg', '000666.jpg', '000949.jpg', '000813.jpg', '001507.jpg', '000397.jpg', '000380.jpg', '001030.jpg', '001064.jpg', '000321.jpg', '000164.jpg', '001583.jpg', ' ...

# %% [markdown]
# # Hyperparameters
# - image size
# - train path
# - epochs
# - validation size
# - Generator Declaration

# %%
image_size = (218,178)
train_path = '/home/von/Downloads/archive(1)/Dataset'
epochs = 50
validation_size = 16

# %% [markdown]
# # Utility Function

# %% [markdown]
# # Data Generator

# %%
class DataGenerator(keras.utils.Sequence):
    def __init__(self,ids,filepath,batch_size=16,image_size=(480,640),channels=3):
        self.ids=ids
        self.filepath=filepath
        self.batch_size=batch_size
        self.image_size=image_size
        self.channels=channels
        
    def __len__(self):
            return (len(self.ids)//self.batch_size)
                   
                     
    def __getitem__(self,index):
            indexes = range(index*self.batch_size,index*self.batch_size+self.batch_size)
            
            ids_to_load = [self.ids[k] for k in indexes]
            X = self.__generate_x(ids_to_load)
            y = self.__generate_y(ids_to_load)
            l = []
            for i,m in enumerate(X):
                l.append(m.reshape(218,178,3))
            X = np.array(l)
            l = []
            for i,m in enumerate(y):
                l.append(m.reshape(218,178,3))
            y = np.array(l)
            return X,y
            
        
        
    def __generate_x(self,id_names):
            X = np.zeros((self.batch_size,self.image_size[0],self.image_size[1],self.channels))
            for i,id_n in enumerate(id_names):
                #print(self.filepath+'/sketch/'+id_n+'-sz1.jpg')
                img = cv2.imread(self.filepath+'/Nepceleb_sketch/'+id_n)
                '''plt.imshow(img)
                plt.show()'''
                img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                
                img = img.astype(np.float32)/255.
                
                img = cv2.resize(img,(self.image_size[0],self.image_size[1]))
                '''plt.imshow(img)
                plt.show()'''
                X[i,:,:,:] = img.reshape(self.image_size[0],self.image_size[1],self.channels)
            return X
        
    def __generate_y(self,id_names):
            y = np.zeros((self.batch_size,self.image_size[0],self.image_size[1],self.channels))
            for i,id_n in enumerate(id_names):
                img = cv2.imread(self.filepath+'/Nepceleb/'+id_n)
                img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                img = img.astype(np.float32)/255.
                img = cv2.resize(img,(self.image_size[0],self.image_size[1]))
                '''plt.imshow(img)
                plt.show()'''
                y[i,:,:,:] = img.reshape(self.image_size[0],self.image_size[1],self.channels)
            return y

# %% [markdown]
# # Sample plot of data

# %%
# Dataset split: 80% train / 10% validation / 10% test
train_size = int(len(image_id_list) * 0.8)
val_size = int(len(image_id_list) * 0.1)
test_size = len(image_id_list) - train_size - val_size

train_gen = DataGenerator(image_id_list[:train_size],train_path,batch_size=8,image_size=(178,218),channels=3)
val_gen = DataGenerator(image_id_list[train_size:train_size+val_size],train_path,batch_size=8,image_size=(178,218),channels=3)
test_gen = DataGenerator(image_id_list[train_size+val_size:],train_path,batch_size=8,image_size=(178,218),channels=3)

# %%
X,y = val_gen.__getitem__(1)
val_gen.__len__()
#train_gen.__len__()
# Out:
# 20

# %%
len(image_id_list)
# Out:
# 1626

# %%
X.shape
# Out:
# (8, 218, 178, 3)

# %%
cv2.imwrite('file.jpg',X[1]*255.)
# Out:
# True

# %%
Image(filename='file.jpg')

# %%
plt.imshow(X[1])
plt.show()
plt.imshow(y[1])
plt.show()

# %% [markdown]
# # Loss Function

# %%
def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

# %% [markdown]
# # Different Convolution block

# %%
def get_crop_shape(target, refer):
        # width, the 3rd dimension
        cw = (target.shape[2] - refer.shape[2])
        assert (cw >= 0)
        if cw % 2 != 0:
            cw1, cw2 = int(cw/2), int(cw/2) + 1
        else:
            cw1, cw2 = int(cw/2), int(cw/2)
        # height, the 2nd dimension
        ch = (target.shape[1] - refer.shape[1])
        assert (ch >= 0)
        if ch % 2 != 0:
            ch1, ch2 = int(ch/2), int(ch/2) + 1
        else:
            ch1, ch2 = int(ch/2), int(ch/2)

        return (ch1, ch2), (cw1, cw2)





def down_block(x,filters,kernel_size=(3,3),strides=1,padding='same',activation='relu'):
    c = Conv2D(filters,kernel_size=kernel_size,padding=padding,strides=strides,activation=activation)(x)
    c = Conv2D(filters,kernel_size=kernel_size,padding=padding,strides=strides,activation=activation)(c)
    p = MaxPooling2D((2,2))(c)
    return c,p

def up_block(x,skip,filters,kernel_size=(3,3),strides=1,padding='same',activation='relu'):
    us = UpSampling2D((2,2))(x)
    ch, cw = get_crop_shape(skip,us)
    us = ZeroPadding2D(padding = (ch,cw))(us)
    #ch, cw = get_crop_shape(skip,us)
    #skip = Cropping2D(cropping=(ch,cw))(skip)
    us = Concatenate()([us,skip])
    us = Conv2D(filters,kernel_size,padding=padding,strides=strides,activation=activation)(us)
    us = Conv2D(filters,kernel_size,padding=padding,strides=strides,activation=activation)(us)
    return us
    
def bottleneck(x,filters,kernel_size=(3,3),strides=1,padding='same',activation='relu'):
    b = Conv2D(filters,kernel_size,padding=padding,strides=strides,activation=activation)(x)
    b = Conv2D(filters,kernel_size,padding=padding,strides=strides,activation=activation)(b)
    return b

# %% [markdown]
# # Unet Model

# %%
def Unet():
    f = [16,32,64,128,256]
    inputs = Input((image_size[0],image_size[1],3))
    
    c1,p1 = down_block(inputs,f[0])#350->175, 525->262
    c2,p2 = down_block(p1,f[1])#175->87, 262-> 131
    c3,p3 = down_block(p2,f[2])#87->43, 131 -> 65 
    c4,p4 = down_block(p3,f[3])#43->21, 65->32
    b = bottleneck(p4,f[4])#21,32
    u1 = up_block(b,c4,f[3])#
    u2 = up_block(u1,c3,f[2])#16->32
    u3 = up_block(u2,c2,f[1])#32->64
    u4 = up_block(u3,c1,f[0])#64->128
    
    outputs = Conv2D(3,(1,1),padding='same',activation='sigmoid')(u4)
    
    model = Model(inputs,outputs)
    
    return model

# %% [markdown]
# # Training the Model

# %%
model = Unet()
model.compile(optimizer='adam', loss='mean_squared_error', metrics=[dice_loss])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 218, 178, 3)]        0         []
#
#  conv2d_19 (Conv2D)          (None, 218, 178, 16)         448       ['input_2[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 218, 178, 16)         2320      ['conv2d_19[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 109, 89, 16)          0         ['conv2d_20[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 109, 89, 32)          4640      ['max_pooling2d_4[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 109, 89, 32)          9248      ['conv2d_21[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 54, 44, 32)           0         ['conv2d_22[0][0]']
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 54, 44, 64)           18496     ['max_pooling2d_5[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 54, 44, 64)           36928     ['conv2d_23[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 27, 22, 64)           0         ['conv2d_24[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 27, 22, 128)          73856     ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 27, 22, 128)          147584    ['conv2d_25[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 13, 11, 128)          0         ['conv2d_26[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 13, 11, 256)          295168    ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 13, 11, 256)          590080    ['conv2d_27[0][0]']
#
#  up_sampling2d_4 (UpSamplin  (None, 26, 22, 256)          0         ['conv2d_28[0][0]']
#  g2D)
#
#  zero_padding2d_4 (ZeroPadd  (None, 27, 22, 256)          0         ['up_sampling2d_4[0][0]']
#  ing2D)
#
#  concatenate_4 (Concatenate  (None, 27, 22, 384)          0         ['zero_padding2d_4[0][0]',
#  )                                                                   'conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 27, 22, 128)          442496    ['concatenate_4[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 27, 22, 128)          147584    ['conv2d_29[0][0]']
#
#  up_sampling2d_5 (UpSamplin  (None, 54, 44, 128)          0         ['conv2d_30[0][0]']
#  g2D)
#
#  zero_padding2d_5 (ZeroPadd  (None, 54, 44, 128)          0         ['up_sampling2d_5[0][0]']
#  ing2D)
#
#  concatenate_5 (Concatenate  (None, 54, 44, 192)          0         ['zero_padding2d_5[0][0]',
#  )                                                                   'conv2d_24[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 54, 44, 64)           110656    ['concatenate_5[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 54, 44, 64)           36928     ['conv2d_31[0][0]']
#
#  up_sampling2d_6 (UpSamplin  (None, 108, 88, 64)          0         ['conv2d_32[0][0]']
#  g2D)
#
#  zero_padding2d_6 (ZeroPadd  (None, 109, 89, 64)          0         ['up_sampling2d_6[0][0]']
#  ing2D)
#
#  concatenate_6 (Concatenate  (None, 109, 89, 96)          0         ['zero_padding2d_6[0][0]',
#  )                                                                   'conv2d_22[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 109, 89, 32)          27680     ['concatenate_6[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 109, 89, 32)          9248      ['conv2d_33[0][0]']
#
#  up_sampling2d_7 (UpSamplin  (None, 218, 178, 32)         0         ['conv2d_34[0][0]']
#  g2D)
#
#  zero_padding2d_7 (ZeroPadd  (None, 218, 178, 32)         0         ['up_sampling2d_7[0][0]']
#  ing2D)
#
#  concatenate_7 (Concatenate  (None, 218, 178, 48)         0         ['zero_padding2d_7[0][0]',
#  )                                                                   'conv2d_20[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 218, 178, 16)         6928      ['concatenate_7[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 218, 178, 16)         2320      ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 218, 178, 3)          51        ['conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 1962659 (7.49 MB)
# Trainable params: 1962659 (7.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Train the model using fit or fit_generator
history = model.fit(
    train_gen,
    epochs=epochs,
    validation_data=val_gen,
    verbose=1  # Set verbose to control logging output
)

# Visualization outside the loop for efficiency
val_x, val_y = val_gen.__getitem__(0)  # Get one batch for validation visualization
pred_y = model.predict(val_x)

# Plot predictions and ground truths
for i in range(min(len(pred_y), 5)):  # Show up to 5 examples
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(pred_y[i])
    plt.title('Predicted')
    
    plt.subplot(1, 2, 2)
    plt.imshow(val_y[i])
    plt.title('Expected')
    
    plt.show()
# Out:
# Epoch 1/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0115 - dice_loss: 0.4069 - val_loss: 0.0237 - val_dice_loss: 0.3958
# Epoch 2/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0105 - dice_loss: 0.4049 - val_loss: 0.0242 - val_dice_loss: 0.3974
# Epoch 3/50
# 162/162 [==============================] - 14s 88ms/step - loss: 0.0095 - dice_loss: 0.4025 - val_loss: 0.0249 - val_dice_loss: 0.4146
# Epoch 4/50
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0089 - dice_loss: 0.4013 - val_loss: 0.0240 - val_dice_loss: 0.3982
# Epoch 5/50
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0085 - dice_loss: 0.4003 - val_loss: 0.0235 - val_dice_loss: 0.3926
# Epoch 6/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0079 - dice_loss: 0.3990 - val_loss: 0.0245 - val_dice_loss: 0.4157
# Epoch 7/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0074 - dice_loss: 0.3979 - val_loss: 0.0232 - val_dice_loss: 0.4035
# Epoch 8/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0071 - dice_loss: 0.3970 - val_loss: 0.0256 - val_dice_loss: 0.4157
# Epoch 9/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0073 - dice_loss: 0.3977 - val_loss: 0.0243 - val_dice_loss: 0.4079
# Epoch 10/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0068 - dice_loss: 0.3964 - val_loss: 0.0237 - val_dice_loss: 0.4000
# Epoch 11/50
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0063 - dice_loss: 0.3952 - val_loss: 0.0233 - val_dice_loss: 0.3989
# Epoch 12/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0059 - dice_loss: 0.3945 - val_loss: 0.0237 - val_dice_loss: 0.4104
# Epoch 13/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0059 - dice_loss: 0.3945 - val_loss: 0.0238 - val_dice_loss: 0.3914
# Epoch 14/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0060 - dice_loss: 0.3946 - val_loss: 0.0237 - val_dice_loss: 0.4023
# Epoch 15/50
# 162/162 [==============================] - 14s 89ms/step - loss: 0.0058 - dice_loss: 0.3941 - val_loss: 0.0244 - val_dice_loss: 0.4052
# Epoch 16/50
# 162/162 [==============================] - 14s 89ms/step - loss: 0.0057 - dice_loss: 0.3939 - val_loss: 0.0237 - val_dice_loss: 0.4061
# Epoch 17/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0050 - dice_loss: 0.3923 - val_loss: 0.0233 - val_dice_loss: 0.3951
# Epoch 18/50
# 162/162 [==============================] - 14s 88ms/step - loss: 0.0046 - dice_loss: 0.3918 - val_loss: 0.0238 - val_dice_loss: 0.3894
# Epoch 19/50
# 162/162 [==============================] - 15s 90ms/step - loss: 0.0044 - dice_loss: 0.3909 - val_loss: 0.0233 - val_dice_loss: 0.3986
# Epoch 20/50
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0043 - dice_loss: 0.3908 - val_loss: 0.0232 - val_dice_loss: 0.4011
# Epoch 21/50
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0045 - dice_loss: 0.3912 - val_loss: 0.0235 - val_dice_loss: 0.3914
# Epoch 22/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0045 - dice_loss: 0.3912 - val_loss: 0.0230 - val_dice_loss: 0.4010
# Epoch 23/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0046 - dice_loss: 0.3913 - val_loss: 0.0229 - val_dice_loss: 0.4035
# Epoch 24/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0042 - dice_loss: 0.3907 - val_loss: 0.0234 - val_dice_loss: 0.4037
# Epoch 25/50
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0039 - dice_loss: 0.3898 - val_loss: 0.0234 - val_dice_loss: 0.3940
# Epoch 26/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0037 - dice_loss: 0.3895 - val_loss: 0.0233 - val_dice_loss: 0.4046
# Epoch 27/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0037 - dice_loss: 0.3894 - val_loss: 0.0230 - val_dice_loss: 0.3986
# Epoch 28/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0036 - dice_loss: 0.3891 - val_loss: 0.0235 - val_dice_loss: 0.4034
# Epoch 29/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0038 - dice_loss: 0.3898 - val_loss: 0.0231 - val_dice_loss: 0.4034
# Epoch 30/50
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0040 - dice_loss: 0.3898 - val_loss: 0.0228 - val_dice_loss: 0.4009
# Epoch 31/50
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0037 - dice_loss: 0.3895 - val_loss: 0.0232 - val_dice_loss: 0.4019
# Epoch 32/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0038 - dice_loss: 0.3896 - val_loss: 0.0232 - val_dice_loss: 0.4036
# Epoch 33/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0038 - dice_loss: 0.3897 - val_loss: 0.0231 - val_dice_loss: 0.4006
# Epoch 34/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0036 - dice_loss: 0.3892 - val_loss: 0.0234 - val_dice_loss: 0.3877
# Epoch 35/50
# 162/162 [==============================] - 14s 84ms/step - loss: 0.0035 - dice_loss: 0.3888 - val_loss: 0.0231 - val_dice_loss: 0.4016
# Epoch 36/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0034 - dice_loss: 0.3888 - val_loss: 0.0230 - val_dice_loss: 0.4025
# Epoch 37/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0033 - dice_loss: 0.3885 - val_loss: 0.0225 - val_dice_loss: 0.3988
# Epoch 38/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0038 - dice_loss: 0.3896 - val_loss: 0.0246 - val_dice_loss: 0.4106
# Epoch 39/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0084 - dice_loss: 0.3994 - val_loss: 0.0257 - val_dice_loss: 0.4090
# Epoch 40/50
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0045 - dice_loss: 0.3911 - val_loss: 0.0235 - val_dice_loss: 0.4008
# Epoch 41/50
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0034 - dice_loss: 0.3889 - val_loss: 0.0228 - val_dice_loss: 0.3991
# Epoch 42/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0030 - dice_loss: 0.3879 - val_loss: 0.0226 - val_dice_loss: 0.3999
# Epoch 43/50
# 162/162 [==============================] - 14s 83ms/step - loss: 0.0029 - dice_loss: 0.3876 - val_loss: 0.0228 - val_dice_loss: 0.3974
# Epoch 44/50
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0027 - dice_loss: 0.3872 - val_loss: 0.0228 - val_dice_loss: 0.4036
# Epoch 45/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0027 - dice_loss: 0.3872 - val_loss: 0.0226 - val_dice_loss: 0.4022
# Epoch 46/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0028 - dice_loss: 0.3874 - val_loss: 0.0229 - val_dice_loss: 0.3974
# Epoch 47/50
# 162/162 [==============================] - 14s 84ms/step - loss: 0.0030 - dice_loss: 0.3876 - val_loss: 0.0224 - val_dice_loss: 0.4022
# Epoch 48/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0031 - dice_loss: 0.3883 - val_loss: 0.0229 - val_dice_loss: 0.3983
# Epoch 49/50
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0031 - dice_loss: 0.3880 - val_loss: 0.0227 - val_dice_loss: 0.3986
# Epoch 50/50
# 162/162 [==============================] - 14s 84ms/step - loss: 0.0033 - dice_loss: 0.3884 - val_loss: 0.0227 - val_dice_loss: 0.3996
# 1/1 [==============================] - 0s 34ms/step

# %%
checkpoint = ModelCheckpoint('model.h5', save_best_only=True)
checkpoint2 = ModelCheckpoint("best_model.hdf5", monitor='loss', verbose=1,save_weights_only =True,
    save_best_only=True, mode='auto', period=1)
history = model.fit_generator(train_gen,epochs = epochs,validation_data = val_gen,callbacks=[checkpoint2,checkpoint])
with open('history.pickle','wb') as file:
    pickle.dump(history.history,file)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# /tmp/ipykernel_7158/2985032710.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_gen,epochs = epochs,validation_data = val_gen,callbacks=[checkpoint2,checkpoint])
# 162/162 [==============================] - ETA: 0s - loss: 0.0030 - dice_loss: 0.3879
# Epoch 1: loss improved from inf to 0.00298, saving model to best_model.hdf5
# 162/162 [==============================] - 15s 89ms/step - loss: 0.0030 - dice_loss: 0.3879 - val_loss: 0.0229 - val_dice_loss: 0.3977
# Epoch 2/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0027 - dice_loss: 0.3873
# Epoch 2: loss improved from 0.00298 to 0.00275, saving model to best_model.hdf5
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0027 - dice_loss: 0.3873 - val_loss: 0.0227 - val_dice_loss: 0.4026
# Epoch 3/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0028 - dice_loss: 0.3874
# Epoch 3: loss did not improve from 0.00275
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0028 - dice_loss: 0.3874 - val_loss: 0.0227 - val_dice_loss: 0.4010
# Epoch 4/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0028 - dice_loss: 0.3874
# Epoch 4: loss did not improve from 0.00275
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0028 - dice_loss: 0.3874 - val_loss: 0.0227 - val_dice_loss: 0.4028
# Epoch 5/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0029 - dice_loss: 0.3876
# Epoch 5: loss did not improve from 0.00275
# 162/162 [==============================] - 14s 84ms/step - loss: 0.0029 - dice_loss: 0.3876 - val_loss: 0.0230 - val_dice_loss: 0.4009
# Epoch 6/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0028 - dice_loss: 0.3873
# Epoch 6: loss did not improve from 0.00275
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0028 - dice_loss: 0.3873 - val_loss: 0.0230 - val_dice_loss: 0.4043
# Epoch 7/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0028 - dice_loss: 0.3876
# Epoch 7: loss did not improve from 0.00275
# 162/162 [==============================] - 14s 84ms/step - loss: 0.0028 - dice_loss: 0.3876 - val_loss: 0.0229 - val_dice_loss: 0.4045
# Epoch 8/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0030 - dice_loss: 0.3876
# Epoch 8: loss did not improve from 0.00275
# 162/162 [==============================] - 13s 83ms/step - loss: 0.0030 - dice_loss: 0.3876 - val_loss: 0.0230 - val_dice_loss: 0.4040
# Epoch 9/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0089 - dice_loss: 0.4003
# Epoch 9: loss did not improve from 0.00275
# 162/162 [==============================] - 14s 83ms/step - loss: 0.0089 - dice_loss: 0.4003 - val_loss: 0.0253 - val_dice_loss: 0.4062
# Epoch 10/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0049 - dice_loss: 0.3921
# Epoch 10: loss did not improve from 0.00275
# 162/162 [==============================] - 14s 83ms/step - loss: 0.0049 - dice_loss: 0.3921 - val_loss: 0.0235 - val_dice_loss: 0.4014
# Epoch 11/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0034 - dice_loss: 0.3886
# Epoch 11: loss did not improve from 0.00275
# 162/162 [==============================] - 13s 83ms/step - loss: 0.0034 - dice_loss: 0.3886 - val_loss: 0.0231 - val_dice_loss: 0.4012
# Epoch 12/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0028 - dice_loss: 0.3873
# Epoch 12: loss did not improve from 0.00275
# 162/162 [==============================] - 14s 83ms/step - loss: 0.0028 - dice_loss: 0.3873 - val_loss: 0.0231 - val_dice_loss: 0.4067
# Epoch 13/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0025 - dice_loss: 0.3868
# Epoch 13: loss improved from 0.00275 to 0.00249, saving model to best_model.hdf5
# 162/162 [==============================] - 14s 84ms/step - loss: 0.0025 - dice_loss: 0.3868 - val_loss: 0.0231 - val_dice_loss: 0.4086
# Epoch 14/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0023 - dice_loss: 0.3866
# Epoch 14: loss improved from 0.00249 to 0.00234, saving model to best_model.hdf5
# 162/162 [==============================] - 14s 84ms/step - loss: 0.0023 - dice_loss: 0.3866 - val_loss: 0.0227 - val_dice_loss: 0.4040
# Epoch 15/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0023 - dice_loss: 0.3864
# Epoch 15: loss improved from 0.00234 to 0.00230, saving model to best_model.hdf5
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0023 - dice_loss: 0.3864 - val_loss: 0.0226 - val_dice_loss: 0.4043
# Epoch 16/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0023 - dice_loss: 0.3864
# Epoch 16: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 83ms/step - loss: 0.0023 - dice_loss: 0.3864 - val_loss: 0.0228 - val_dice_loss: 0.4004
# Epoch 17/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0025 - dice_loss: 0.3869
# Epoch 17: loss did not improve from 0.00230
# 162/162 [==============================] - 13s 83ms/step - loss: 0.0025 - dice_loss: 0.3869 - val_loss: 0.0228 - val_dice_loss: 0.4036
# Epoch 18/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0027 - dice_loss: 0.3872
# Epoch 18: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 83ms/step - loss: 0.0027 - dice_loss: 0.3872 - val_loss: 0.0230 - val_dice_loss: 0.4082
# Epoch 19/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0026 - dice_loss: 0.3870
# Epoch 19: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0026 - dice_loss: 0.3870 - val_loss: 0.0232 - val_dice_loss: 0.4069
# Epoch 20/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0025 - dice_loss: 0.3868
# Epoch 20: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0025 - dice_loss: 0.3868 - val_loss: 0.0229 - val_dice_loss: 0.4015
# Epoch 21/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0025 - dice_loss: 0.3866
# Epoch 21: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0025 - dice_loss: 0.3866 - val_loss: 0.0231 - val_dice_loss: 0.4029
# Epoch 22/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0026 - dice_loss: 0.3870
# Epoch 22: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0026 - dice_loss: 0.3870 - val_loss: 0.0229 - val_dice_loss: 0.4055
# Epoch 23/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0025 - dice_loss: 0.3868
# Epoch 23: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0025 - dice_loss: 0.3868 - val_loss: 0.0228 - val_dice_loss: 0.4061
# Epoch 24/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0027 - dice_loss: 0.3873
# Epoch 24: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0027 - dice_loss: 0.3873 - val_loss: 0.0229 - val_dice_loss: 0.4021
# Epoch 25/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0029 - dice_loss: 0.3875
# Epoch 25: loss did not improve from 0.00230
# 162/162 [==============================] - 15s 91ms/step - loss: 0.0029 - dice_loss: 0.3875 - val_loss: 0.0226 - val_dice_loss: 0.4031
# Epoch 26/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0026 - dice_loss: 0.3869
# Epoch 26: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0026 - dice_loss: 0.3869 - val_loss: 0.0227 - val_dice_loss: 0.4019
# Epoch 27/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0023 - dice_loss: 0.3864
# Epoch 27: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0023 - dice_loss: 0.3864 - val_loss: 0.0230 - val_dice_loss: 0.4107
# Epoch 28/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0023 - dice_loss: 0.3865
# Epoch 28: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0023 - dice_loss: 0.3865 - val_loss: 0.0227 - val_dice_loss: 0.4064
# Epoch 29/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0023 - dice_loss: 0.3864
# Epoch 29: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 88ms/step - loss: 0.0023 - dice_loss: 0.3864 - val_loss: 0.0225 - val_dice_loss: 0.4009
# Epoch 30/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0025 - dice_loss: 0.3865
# Epoch 30: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 84ms/step - loss: 0.0025 - dice_loss: 0.3865 - val_loss: 0.0229 - val_dice_loss: 0.3933
# Epoch 31/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0026 - dice_loss: 0.3872
# Epoch 31: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 85ms/step - loss: 0.0026 - dice_loss: 0.3872 - val_loss: 0.0230 - val_dice_loss: 0.3941
# Epoch 32/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0027 - dice_loss: 0.3873
# Epoch 32: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0027 - dice_loss: 0.3873 - val_loss: 0.0228 - val_dice_loss: 0.4071
# Epoch 33/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0028 - dice_loss: 0.3873
# Epoch 33: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0028 - dice_loss: 0.3873 - val_loss: 0.0226 - val_dice_loss: 0.4020
# Epoch 34/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0030 - dice_loss: 0.3877
# Epoch 34: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0030 - dice_loss: 0.3877 - val_loss: 0.0237 - val_dice_loss: 0.4121
# Epoch 35/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0026 - dice_loss: 0.3871
# Epoch 35: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0026 - dice_loss: 0.3871 - val_loss: 0.0236 - val_dice_loss: 0.4121
# Epoch 36/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0025 - dice_loss: 0.3868
# Epoch 36: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 88ms/step - loss: 0.0025 - dice_loss: 0.3868 - val_loss: 0.0234 - val_dice_loss: 0.4118
# Epoch 37/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0025 - dice_loss: 0.3869
# Epoch 37: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 87ms/step - loss: 0.0025 - dice_loss: 0.3869 - val_loss: 0.0225 - val_dice_loss: 0.4022
# Epoch 38/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0024 - dice_loss: 0.3863
# Epoch 38: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0024 - dice_loss: 0.3863 - val_loss: 0.0231 - val_dice_loss: 0.4076
# Epoch 39/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0024 - dice_loss: 0.3866
# Epoch 39: loss did not improve from 0.00230
# 162/162 [==============================] - 14s 89ms/step - loss: 0.0024 - dice_loss: 0.3866 - val_loss: 0.0224 - val_dice_loss: 0.4029
# Epoch 40/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0023 - dice_loss: 0.3861
# Epoch 40: loss improved from 0.00230 to 0.00227, saving model to best_model.hdf5
# 162/162 [==============================] - 16s 97ms/step - loss: 0.0023 - dice_loss: 0.3861 - val_loss: 0.0225 - val_dice_loss: 0.3967
# Epoch 41/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0022 - dice_loss: 0.3863
# Epoch 41: loss improved from 0.00227 to 0.00223, saving model to best_model.hdf5
# 162/162 [==============================] - 19s 119ms/step - loss: 0.0022 - dice_loss: 0.3863 - val_loss: 0.0224 - val_dice_loss: 0.4027
# Epoch 42/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0022 - dice_loss: 0.3860
# Epoch 42: loss improved from 0.00223 to 0.00216, saving model to best_model.hdf5
# 162/162 [==============================] - 19s 116ms/step - loss: 0.0022 - dice_loss: 0.3860 - val_loss: 0.0223 - val_dice_loss: 0.3989
# Epoch 43/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0021 - dice_loss: 0.3858
# Epoch 43: loss improved from 0.00216 to 0.00205, saving model to best_model.hdf5
# 162/162 [==============================] - 18s 114ms/step - loss: 0.0021 - dice_loss: 0.3858 - val_loss: 0.0222 - val_dice_loss: 0.4005
# Epoch 44/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0020 - dice_loss: 0.3857
# Epoch 44: loss improved from 0.00205 to 0.00204, saving model to best_model.hdf5
# 162/162 [==============================] - 18s 112ms/step - loss: 0.0020 - dice_loss: 0.3857 - val_loss: 0.0223 - val_dice_loss: 0.4030
# Epoch 45/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0021 - dice_loss: 0.3858
# Epoch 45: loss did not improve from 0.00204
# 162/162 [==============================] - 18s 110ms/step - loss: 0.0021 - dice_loss: 0.3858 - val_loss: 0.0223 - val_dice_loss: 0.4017
# Epoch 46/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0025 - dice_loss: 0.3866
# Epoch 46: loss did not improve from 0.00204
# 162/162 [==============================] - 17s 108ms/step - loss: 0.0025 - dice_loss: 0.3866 - val_loss: 0.0223 - val_dice_loss: 0.3958
# Epoch 47/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0024 - dice_loss: 0.3864
# Epoch 47: loss did not improve from 0.00204
# 162/162 [==============================] - 14s 84ms/step - loss: 0.0024 - dice_loss: 0.3864 - val_loss: 0.0235 - val_dice_loss: 0.4132
# Epoch 48/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0027 - dice_loss: 0.3872
# Epoch 48: loss did not improve from 0.00204
# 162/162 [==============================] - 14s 86ms/step - loss: 0.0027 - dice_loss: 0.3872 - val_loss: 0.0227 - val_dice_loss: 0.4022
# Epoch 49/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0025 - dice_loss: 0.3868
# Epoch 49: loss did not improve from 0.00204
# 162/162 [==============================] - 14s 84ms/step - loss: 0.0025 - dice_loss: 0.3868 - val_loss: 0.0229 - val_dice_loss: 0.3950
# Epoch 50/50
# 162/162 [==============================] - ETA: 0s - loss: 0.0028 - dice_loss: 0.3872
# Epoch 50: loss did not improve from 0.00204
# 162/162 [==============================] - 14s 84ms/step - loss: 0.0028 - dice_loss: 0.3872 - val_loss: 0.0226 - val_dice_loss: 0.4038

# %% [markdown]
# # Testing the Model

# %%
# Load model
model = load_model('model.h5', custom_objects={'dice_loss': dice_loss})

# Load weights instead of model
model.load_weights('best_model.hdf5')

# Load and preprocess image
img = cv2.imread('image.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
img = cv2.resize(img, (178, 218))  # Resize to match model input size
img = img.astype(np.float32) / 255.0  # Normalize the image to range [0, 1]

# Visualize the original and preprocessed images
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(cv2.imread('image.jpg'), cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(img)
plt.title('Preprocessed Image')

plt.show()

# Create a batch of 16 images (replicate the image 16 times)
img_batch = np.repeat(img[np.newaxis, ...], 16, axis=0)

# Predict with the model (reshape image for model input)
img_input = img.reshape(1, 218, 178, 3)
#y_pred = model.predict(img_input)
y_pred = model.predict(img_batch)

# Visualize the predicted image
plt.figure(figsize=(10, 5))
plt.imshow(y_pred[0])  # Display the predicted image
plt.title('Predicted Image')
plt.show()

# Optionally, save the predicted image
#matplotlib.image.imsave('predicted_image.png', y_pred[0])

# Check max value of the image for diagnostics
print(f"Max value in the image: {np.max(img.flatten())}")
# Out:
# 1/1 [==============================] - 4s 4s/step
# Max value in the image: 1.0

# %%
# Get the validation data
val_x, val_y = val_gen.__getitem__(0)
pred_y = model.predict(val_x)

# Determine an appropriate win_size 
win_size = 3  

# Calculate the data_range based on the images' min and max values
data_range = val_y.max() - val_y.min()

# Calculate SSIM for each image in the batch
ssim_scores = [
    ssim(val_y[i], pred_y[i], multichannel=True, win_size=win_size, data_range=data_range) for i in range(len(val_y))
]

# Print average SSIM score
avg_ssim = np.mean(ssim_scores)
print(f"Average SSIM: {avg_ssim:.4f}")

# Flatten the images for ROC curve calculation
val_y_flat = val_y.flatten()
pred_y_flat = pred_y.flatten()

# Ensure binary labels for ROC curve
val_y_flat = np.round(val_y_flat)  
pred_y_flat = np.clip(pred_y_flat, 0, 1)  

# Calculate the ROC curve
fpr, tpr, _ = roc_curve(val_y_flat, pred_y_flat)
roc_auc = auc(fpr, tpr)

# Plotting the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.grid(True)

# Save the plot as an image
plt.savefig('./accuracy/roc_curve.png')


plt.show()
# Out:
# 1/1 [==============================] - 0s 390ms/step
# Average SSIM: 0.3030

# %%
model = load_model('model.h5', custom_objects={'dice_loss': dice_loss})

# Load and preprocess image
img = cv2.imread('ok.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
img = cv2.resize(img, (178, 218))  # Resize to match model input size
img = img.astype(np.float32) / 255.0  # Normalize the image to range [0, 1]

# Visualize the original and preprocessed images
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(cv2.imread('ok.jpg'), cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(img)
plt.title('Preprocessed Image')

plt.show()

# Create a batch of 16 images (replicate the image 16 times)
img_batch = np.repeat(img[np.newaxis, ...], 16, axis=0)

# Predict with the model (use img_batch)
y_pred = model.predict(img_batch)

# Apply post-processing (darken the image and enhance)
y_pred = np.squeeze(y_pred)  # Remove batch dimension
y_pred = np.clip(y_pred, 0, 1)  # Ensure output is in range [0, 1]

# Darken the predicted image
darkened_img = np.clip(y_pred[0] * 0.5, 0, 1)  # Darken by 50%

# Enhance contrast (stretch pixel values)
enhanced_contrast_img = np.clip((darkened_img - 0.5) * 1.5 + 0.5, 0, 1)

# Boost saturation (increase color intensity)
enhanced_color_img = np.clip(enhanced_contrast_img * 1.3, 0, 1)  # Boost saturation by 30%

# Visualize the enhanced image
plt.figure(figsize=(10, 5))
plt.imshow(enhanced_color_img)
plt.title('Enhanced Predicted Image')
plt.show()

# Optionally, save the enhanced image
# matplotlib.image.imsave('enhanced_predicted_image.png', enhanced_color_img)

# Check max value of the enhanced image for diagnostics
print(f"Max value in the enhanced image: {np.max(enhanced_color_img.flatten())}")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x732c38528160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 156ms/step
# Max value in the enhanced image: 0.6372385025024414

# %%
import pickle
import matplotlib.pyplot as plt

# Load the history from the pickle file
with open('history.pickle', 'rb') as file:
    history = pickle.load(file)

# Extract the Dice loss values
dice_loss = history.get('dice_loss', [])
val_dice_loss = history.get('val_dice_loss', [])

# Get the number of epochs (assuming the length of dice_loss matches the number of epochs)
epochs = range(1, len(dice_loss) + 1)

# Plot the Dice loss for training and validation
plt.plot(epochs, dice_loss, label='Training Dice Loss')
plt.plot(epochs, val_dice_loss, label='Validation Dice Loss')
plt.xlabel('Epochs')
plt.ylabel('Dice Loss')
plt.title('Dice Loss vs Epochs')
plt.legend()
plt.show()

# %%
def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    return intersection / (union + K.epsilon())

model = Unet()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[dice_loss, iou])
# Train the model using fit or fit_generator
history = model.fit(
    train_gen,
    epochs=15,
    validation_data=val_gen,
    verbose=1  # Set verbose to control logging output
)

# Visualization outside the loop for efficiency
val_x, val_y = val_gen.__getitem__(0)  # Get one batch for validation visualization
pred_y = model.predict(val_x)

# Plot predictions and ground truths
for i in range(min(len(pred_y), 5)):  # Show up to 5 examples
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(pred_y[i])
    plt.title('Predicted')
    
    plt.subplot(1, 2, 2)
    plt.imshow(val_y[i])
    plt.title('Expected')
    
    plt.show()
# Out:
# 2025-03-05 09:11:58.645086: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-05 09:11:58.798844: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-05 09:11:58.800167: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-05 09:11:58.802775: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-05 09:11:58.804798: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-05 09:11:58.806020: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-05 09:11:58.947406: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-05 09:11:58.948740: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-05 09:11:58.949961: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-03-05 09:11:58.951103: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2303 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/15
# 2025-03-05 09:12:01.488536: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2025-03-05 09:12:05.017255: I external/local_xla/xla/service/service.cc:168] XLA service 0x7dd6a14bae70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-03-05 09:12:05.017284: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2025-03-05 09:12:05.028211: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741145225.141032    6918 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 162/162 [==============================] - 27s 88ms/step - loss: 0.6365 - dice_loss: 0.5160 - iou: 0.3198 - val_loss: 0.6292 - val_dice_loss: 0.5011 - val_iou: 0.3325
# Epoch 2/15
# 162/162 [==============================] - 14s 88ms/step - loss: 0.6166 - dice_loss: 0.4976 - iou: 0.3361 - val_loss: 0.5988 - val_dice_loss: 0.4616 - val_iou: 0.3686
# Epoch 3/15
# 162/162 [==============================] - 14s 89ms/step - loss: 0.6015 - dice_loss: 0.4787 - iou: 0.3531 - val_loss: 0.5918 - val_dice_loss: 0.4593 - val_iou: 0.3708
# Epoch 4/15
# 162/162 [==============================] - 15s 91ms/step - loss: 0.5906 - dice_loss: 0.4672 - iou: 0.3639 - val_loss: 0.5926 - val_dice_loss: 0.4765 - val_iou: 0.3548
# Epoch 5/15
# 162/162 [==============================] - 14s 87ms/step - loss: 0.5883 - dice_loss: 0.4647 - iou: 0.3661 - val_loss: 0.5846 - val_dice_loss: 0.4355 - val_iou: 0.3936
# Epoch 6/15
# 162/162 [==============================] - 15s 90ms/step - loss: 0.5829 - dice_loss: 0.4593 - iou: 0.3711 - val_loss: 0.5773 - val_dice_loss: 0.4232 - val_iou: 0.4056
# Epoch 7/15
# 162/162 [==============================] - 14s 88ms/step - loss: 0.5819 - dice_loss: 0.4573 - iou: 0.3730 - val_loss: 0.5861 - val_dice_loss: 0.4552 - val_iou: 0.3748
# Epoch 8/15
# 162/162 [==============================] - 15s 90ms/step - loss: 0.5763 - dice_loss: 0.4523 - iou: 0.3778 - val_loss: 0.5715 - val_dice_loss: 0.4220 - val_iou: 0.4068
# Epoch 9/15
# 162/162 [==============================] - 14s 86ms/step - loss: 0.5759 - dice_loss: 0.4506 - iou: 0.3794 - val_loss: 0.5702 - val_dice_loss: 0.4222 - val_iou: 0.4067
# Epoch 10/15
# 162/162 [==============================] - 14s 87ms/step - loss: 0.5695 - dice_loss: 0.4450 - iou: 0.3848 - val_loss: 0.5829 - val_dice_loss: 0.4599 - val_iou: 0.3703
# Epoch 11/15
# 162/162 [==============================] - 14s 86ms/step - loss: 0.5667 - dice_loss: 0.4430 - iou: 0.3867 - val_loss: 0.5654 - val_dice_loss: 0.4207 - val_iou: 0.4082
# Epoch 12/15
# 162/162 [==============================] - 14s 86ms/step - loss: 0.5668 - dice_loss: 0.4421 - iou: 0.3875 - val_loss: 0.5710 - val_dice_loss: 0.3881 - val_iou: 0.4415
# Epoch 13/15
# 162/162 [==============================] - 14s 87ms/step - loss: 0.5638 - dice_loss: 0.4393 - iou: 0.3903 - val_loss: 0.5598 - val_dice_loss: 0.4228 - val_iou: 0.4062
# Epoch 14/15
# 162/162 [==============================] - 14s 86ms/step - loss: 0.5596 - dice_loss: 0.4354 - iou: 0.3941 - val_loss: 0.5716 - val_dice_loss: 0.3889 - val_iou: 0.4406
# Epoch 15/15
# 162/162 [==============================] - 14s 86ms/step - loss: 0.5577 - dice_loss: 0.4339 - iou: 0.3956 - val_loss: 0.5621 - val_dice_loss: 0.4273 - val_iou: 0.4019
# 1/1 [==============================] - 0s 166ms/step
